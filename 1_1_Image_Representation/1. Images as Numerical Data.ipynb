# %% [markdown]
# # Images as Grids of Pixels

# %%
# !git clone https://github.com/Kshitijkc/CVND_Exercises
# Out:
# Cloning into 'CVND_Exercises'...
# remote: Enumerating objects: 768, done.
# remote: Total 768 (delta 0), reused 0 (delta 0), pack-reused 768
# Receiving objects: 100% (768/768), 134.19 MiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# Checking out files: 100% (552/552), done.

# %% [markdown]
# ### Import resources

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image = mpimg.imread('CVND_Exercises/1_1_Image_Representation/images/waymo_car.jpg')

# Print out the image dimensions
print('Image dimensions:', image.shape)

# Change from color to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap='gray')
# Out:
# Image dimensions: (427, 640, 3)

# %%
# Print specific grayscale pixel values
# What is the pixel value at x = 400 and y = 300 (on the body of the car)?

x = 400
y = 300

print(gray_image[y,x])
# Out:
# 159

# %%
#Find the maximum and minimum grayscale values in this image

max_val = np.amax(gray_image)
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)
# Out:
# Max:  255
# Min:  2

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

## TODO: See if you can draw a tiny smiley face or something else!

# %%
# Create a 6x6 image using just grayscale, numerical values
tiny_image = np.array([[0, 255, 255, 255, 255,  0],
                       [0, 255, 255, 255, 0, 255],
                       [0, 255, 255, 0, 255, 255],
                       [0, 255, 0, 0, 255, 255],
                       [0, 0, 255, 255, 0, 255],
                       [0, 255, 255, 255, 255, 0]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')
